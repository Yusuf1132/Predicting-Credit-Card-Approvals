# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = pd.read_csv(r"C:\Users\user\Desktop\Datasets\hw1_data.csv")
x
sns.scatterplot(x= x["Ozone"], y= x["Temp"], hue="Month", data= x)
plt.title("Ozone Vs Temp")
plt.show()
array = np.array([1,2,3,4,5])
array[2]
# Out:
# 3

# %%
print("Hands")
